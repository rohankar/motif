# %% [markdown]
# ## Define User Interface

# %%
import pandas as pd
import numpy as np
import functools
import collections
import operator
pd.options.mode.chained_assignment = None

df = pd.read_excel('song_data2.xlsx')

# Replace NaN values with empty strings

df['entity'] = df['entity'].fillna('')
df['Google_Entities'] = df['Google_Entities'].fillna('')

# Function to convert the genre value in each row to a list  
def list_converter (value):
    return value.split(', ') 
df['genre'] = df['genre'].apply(list_converter)


# Here we define the user interface function the includes all the filters created above

# %%
def UserInterface1(df):
    
    print("In the following steps you will filter the song dataset on the following variables: ")
    [print(i) for i in df.columns.values]
    print("")
    
    ####################
    ###    ARTIST    ###
    ####################
    
    unique_artists = list(df['artist'].unique())
    print ('\nArtist options: ', unique_artists)
    artist_input = input('\nPlease select your artists (or type * to select all): ')

    if artist_input == '*':
        artist_input = unique_artists
    else:
        artist_input = artist_input.split(', ')
    
    # Filtering for artist
    df_filtered = df.loc[df['artist'].isin(artist_input)]
    
    ####################
    ###     ALBUM    ###
    ####################
    
    unique_albums = list(df_filtered['album'].unique())
    print ('\nAlbum options: ', unique_albums)
    album_input = input('\nPlease select your albums (or type * to select all): ')
    
    if album_input == '*':
        album_input = unique_albums
    else:
        album_input = album_input.split(', ')
    
    df_filtered = df_filtered.loc[df_filtered['album'].isin(album_input)]
    
    ####################
    ###   COUNTRY    ###
    ####################
    
    unique_countries = list(df_filtered['home_country'].unique())
    print ('\nCountry options: ', unique_countries)
    country_input = input('\nPlease select your countries (or type * to select all): ')
    
    if country_input == '*':
        country_input = unique_countries
    else:
        country_input = country_input.split(', ')
    
    df_filtered = df_filtered.loc[df_filtered['home_country'].isin(country_input)]
    
    ###################
    ###    GENRE    ###
    ###################

    unflattened_genre_list = list(df_filtered['genre'])
    unique_genres = set([item for sublist in unflattened_genre_list for item in sublist])
    print ('\nGenre options: ', unique_genres)
    
    genre_input = input('\nPlease select your genres (or type * to select all): ')
    
    if genre_input == '*':
        genre_input = list(unique_genres)
    else:
        genre_input = genre_input.split(', ')
    
    df_filtered['genre_match'] = False
    for count, each_row in enumerate(df_filtered['genre']):
        for item in each_row:
            if item in genre_input:
                df_filtered['genre_match'].iloc[count] = True
    df_filtered = df_filtered.loc[df_filtered['genre_match'] == True]
    
    
    ####################
    ### RELEASE YEAR ###
    ####################
    
    print ('\nRelease date options: \n 1960-1969 \n 1970-1979 \n 1980-1989 \n 1990-1999 \n 2000-2009 \n 2010-Present')
    
    release_input = input('\nPlease select your release year (or type * to select all): ')
    
    release_year_list = []

    if release_input == '*':
        for elem in range (1960, 2018):
            release_year_list.append(elem)
    else:
        release_input = release_input.split(', ')
        for elem in release_input:
            if '1960' in elem:
                    for elem in range (1960, 1970):
                        release_year_list.append(elem)
            elif '1970' in elem:
                    for elem in range (1970, 1980):
                        release_year_list.append(elem)
            elif '1980' in elem:
                    for elem in range (1980, 1990):
                        release_year_list.append(elem)
            elif '1990' in elem:
                    for elem in range (1990, 2000):
                        release_year_list.append(elem)
            elif '2000' in elem:
                    for elem in range (2000, 2010):
                        release_year_list.append(elem)
            elif '2010' in elem:
                    for elem in range (2010, 2018):
                        release_year_list.append(elem)

    release_input = release_year_list
    
    df_filtered = df_filtered.loc[df_filtered['released'].isin(release_input)]
    
    ##################
    ### SINGER AGE ###
    ##################
    
    print ('\nSinger age options: \n 10-19 \n 20-29 \n 30-39 \n 40-49 \n 50-59')
    
    age_input = input('\nPlease select an age range for singers (or type * to select all): ')
    
    age_year_list = []

    if age_input == '*':
        for elem in range (10, 56):
            age_year_list.append(elem)
    else:
        age_input = age_input.split(', ')
        for elem in age_input:
            if '10' in elem:
                    for elem in range (10, 20):
                        age_year_list.append(elem)
            elif '20' in elem:
                    for elem in range (20, 30):
                        age_year_list.append(elem)
            elif '30' in elem:
                    for elem in range (30, 40):
                        age_year_list.append(elem)
            elif '40' in elem:
                    for elem in range (40, 50):
                        age_year_list.append(elem)
            elif '50' in elem:
                    for elem in range (50, 57):
                        age_year_list.append(elem)

    age_input = age_year_list
    
    df_filtered = df_filtered.loc[df_filtered['singer_age_at_release'].isin(age_input)]
    
    
    #      ____        _               _   
    #    / __ \      | |             | |  
    #   | |  | |_   _| |_ _ __  _   _| |_ 
    #   | |  | | | | | __| '_ \| | | | __|
    #   | |__| | |_| | |_| |_) | |_| | |_ 
    #    \____/ \__,_|\__| .__/ \__,_|\__|
    #                    | |              
    #                    |_|              
    
    
    print("\n===================================================================\n===================================================================\n")
    
    ## Print average sentiment of songs reslting from filtering ##
    ####
    
    print ('The average sentiment of the songs resulting from your search is: ' + str(round(df_filtered['overall_sentiment'].mean(), 2)))
    
    print("\n===================================================================\n")
    
    ## Return the Top 5 topics and their sentiment for the filtered songs
    ####
    
    print('\nThe top 5 most prevalent topics of the songs resulting from your search are:\n')
    
    df_sentiment_copy = df_filtered.copy()
    df_sentiment_copy = df_sentiment_copy.sort_values(by=['overall_sentiment'], axis=0, ascending=False)[:5]
    df_sentiment_copy = df_sentiment_copy.reset_index()
    
    TopTopics = []
    for i in df['Google_Entities']:
        if i != '':
            for L in eval(i):
                for key,value in L.items():
                    TopTopics.append([key,value])

    li = sorted(TopTopics, key=operator.itemgetter(1), reverse = True)   # Ascending order

    for i in li[:5]:
        print(i[0])
    
    
    #counter = 0
    #while counter < len(df_sentiment_copy['artist']):
    #    print ('Song: "' + (df_sentiment_copy['song'][counter]) + '", Artist: ' + str((df_sentiment_copy['artist'][counter])) + ', '  
    #    + 'Sentiment: ' + str((df_sentiment_copy['overall_sentiment'][counter])))  
    #    print("")
    #    counter +=1
    #
    return df_filtered

# %% [markdown]
# ## Run User Interface

# %%
# Test User Interface
df_filtered = UserInterface1(df)
# Out:
# In the following steps you will filter the song dataset on the following variables:
# ID
# artist
# song
# album
# released
# genre
# home_country
# singer_age_at_release
# entity
# topic
# Google_Entities
# overall_sentiment
#
#
# Artist options:  ['Aerosmith', 'Bruno Mars', 'Coldplay', 'Doors', 'Elton John', 'Elvis Presley', 'Grateful Dead', 'Jimi Hendrix', 'John Legend', 'Lady Gaga', 'Linkin Park', 'Maroon 5', 'Metallica', 'Michael Jackson', 'Nickelback', 'Outkast', 'Santana', 'Stevie Wonder', 'Weezer', 'Wu-Tang Clan']
#
# Please select your artists (or type * to select all): Aerosmith
#
# Album options:  ['Pump', 'Permanent Vacation', 'Nine Lives', 'Aerosmith', "Honkin' on Bobo", 'Just Push Play', 'Draw the Line', 'Rock in a Hard Place']
#
# Please select your albums (or type * to select all): *
#
# Country options:  ['United States']
#
# Please select your countries (or type * to select all): *
#
# Genre options:  {'Hard rock', 'Rock', 'Classic rock'}
#
# Please select your genres (or type * to select all): *
#
# Release date options:
#  1960-1969
#  1970-1979
#  1980-1989
#  1990-1999
#  2000-2009
#  2010-Present
#
# Please select your release year (or type * to select all): *
#
# Singer age options:
#  10-19
#  20-29
#  30-39
#  40-49
#  50-59
#
# Please select an age range for singers (or type * to select all): *
#
# ===================================================================
# ===================================================================
#
# The average sentiment of the songs resulting from your search is: -0.29
#
# ===================================================================
#
#
# The top 5 most prevalent topics of the songs resulting from your search are:
#
# friend
# sight
# fool mess
# times
# Alright

# %%
df_filtered.head()
# Out:
#    ID     artist               song               album  released  \
# 0   1  Aerosmith  Janie's Got A Gun                Pump      1989
# 1   2  Aerosmith        Magic Touch  Permanent Vacation      1987
# 2   3  Aerosmith     Taste Of India          Nine Lives      1997
# 3   4  Aerosmith           Dream On           Aerosmith      1973
# 5   6  Aerosmith        Falling Off          Nine Lives      1997
#
#                   genre   home_country  singer_age_at_release  \
# 0     [Hard rock, Rock]  United States                     41
# 1     [Hard rock, Rock]  United States                     39
# 2           [Hard rock]  United States                     49
# 3  [Classic rock, Rock]  United States                     25
# 5           [Hard rock]  United States                     49
#
#                                               entity  \
# 0  [{"Janie's Got a Gun": 0.2361}, {'Honey': 0.05...
# 1                 [{'Shotgun': 0.1503}, {'babe': 0}]
# 2  [{'Incense': 0.2548}, {'Sweetness of wine': 0....
# 3  [{'Dawn': 0.2379}, {'Sin': 0.2023}, {'Laughter...
# 5  [{'t callI': 0}, {'I saidI': 0}, {'I didn': 0}...
#
#                                                topic  \
# 0  [{'Songs written': 1}, {'Aerosmith songs': 1},...
# 1  [{'Albums': 0.5973}, {'Recorded music': 0.5719...
# 2  [{'Wine': 0.7881}, {'Recorded music': 0.7072},...
# 3  [{'Dawn': 0.3767}, {'Entertainment': 0.3653}, ...
# 5  [{'Literature': 0.3241}, {'Fiction': 0.3006}, ...
#
#                                      Google_Entities  overall_sentiment  \
# 0  [{'Janie': 0.62619865}, {'honey': 0.10297375},...               -0.7
# 1  [{'fire burnin': 0.20596175}, {'Cause': 0.0714...               -0.6
# 2  [{'kind': 0.3166986}, {'taste': 0.23181729}, {...                0.6
# 3  [{'Lord': 0.2157075}, {'Everybody': 0.05828119...                0.0
# 5  [{'way': 0.24776857}, {'man': 0.14769095}, {'h...               -0.6
#
#    genre_match
# 0         True
# 1         True
# 2         True
# 3         True
# 5         True

# %% [markdown]
# ## UI2 RUNNER

# %%
def makeInvertedIndex(df,voctrain):
       
    InvertInd = {}
    
    for word in voctrain:
        InvertInd[word] = []
    

    for j in voctrain:
        for ind, val in enumerate(df['topic']):
            if df['topic'][ind] != '':
                evalue = eval(val) 
                #print(evalue)
                for dual in evalue:
                    for key,value in dual.items():
                        keySplit = key.split(' ')
                        for kS in keySplit:
                            if j == kS:
                                InvertInd[j].append(ind)
    
        
    for j in voctrain:
        for ind, val in enumerate(df['Google_Entities']):
            if df['Google_Entities'][ind] != '':
                evalue = eval(val) 
                for dual in evalue:
                    for key,value in dual.items():
                        keySplit = key.split(' ')
                        for kS in keySplit:
                            if j == kS:
                                InvertInd[j].append(ind)  
    

    for j in voctrain:
        for ind, val in enumerate(df['entity']):
            if df['entity'][ind] != '':
                evalue = eval(val) 
                for dual in evalue:
                    for key,value in dual.items():
                        keySplit = key.split(' ')
                        for kS in keySplit:
                            if j == kS:
                                InvertInd[j].append(ind)
             
        
        
    return InvertInd          



def orSearch(invertedIndex, query, df):
    
    results = []
    
    print("Query is:",query,"\n")
    
    for ask in query:
        print("Check for:",ask)
        if ask in invertedIndex:
            word = invertedIndex[ask]
            print("Found...\n")
            for res in word:
                #print(res)
                if res not in results:
                    results.append(res)
        else:
            print("Not found...\n")
        
    for i in results:
        print(df['song'].iloc[i]," by ", df['artist'].iloc[i])
    #print("Results: ",results)

def andSearch(invertedIndex, query, df):
    
    results = {}
    resultCheck = []
    
    for ask in query:
        results[ask] = []
    
    print("Query is:",query,"\n")
    
    Match = False
    
    for ask in query:
        print("Check for:",ask,"...")
        if ask in invertedIndex:
            word = invertedIndex[ask]
            print("Found\n")
            for res in word:
                results[ask].append(res)
                if res not in resultCheck:
                    resultCheck.append(res)
        else:
            print("Not found\n")
    
    print("Results: ",results)
    
    Matches = []
    
    for check in resultCheck:
        Check = True
        for key,value in results.items():
            if check in value:
                Check = Check and True
            else:
                Check = Check and False
        if Check == True:
            Matches.append(check)
    
    Matches = set (Matches)
    print('\n===================================\n')
    print("Common matches:",Matches,"\n")
    
    for num in Matches:
        print("Found in title: ",df.iloc[num][2], " by ", df.iloc[num][1])
    
def VocBuilder(df):    
    # Create vocabulary for 'entity'

    entity_vocabulary = []

    for i in range(len(df['entity'])):

        if df['entity'][i] != '':
            test = eval(df['entity'][i])
            for j in test:
                for key,value in j.items():
                    temp = key.split(' ')
                    for item in temp:
                        entity_vocabulary.append(item)

    entity_vocabulary = list(set(entity_vocabulary))
    #print(list(set(entity_vocabulary)))


    # Create vocabulary for 'topic'

    topic_vocabulary = []

    for i in range(len(df['topic'])):
        test = eval(df['topic'][i])
        for j in test:
            for key,value in j.items():
                temp = key.split(' ')
                for item in temp:
                    topic_vocabulary.append(item)

    topic_vocabulary = list(set(topic_vocabulary))
    #print(list(set(topic_vocabulary)))


    # Create vocabulary for 'Google_Entities'

    google_entity_vocabulary = []

    for i in range(len(df['topic'])):
        test = eval(df['topic'][i])
        for j in test:
            for key,value in j.items():
                temp = key.split(' ')
                for item in temp:
                    google_entity_vocabulary.append(item)

    google_entity_vocabulary = list(set(google_entity_vocabulary))
    
    # Create vocabularies of individual columns 'entity','topic' and 'Google_Entity' 
    vocabulary_train = entity_vocabulary + topic_vocabulary + google_entity_vocabulary
    vocabulary_train = list(set(vocabulary_train))    
    
    return vocabulary_train
    
def UserInterface2(df):
        
   
    print("In the following steps you will be able to search songs, artists, and albums by Topics and Entities: ")
    print("")
    print ("Lookup topics such as Mars, Fire, Weapons, Love, Death")
    topics_input = input('\nPlease enter topics  (or type * to select some default topics): ')

    if topics_input == '*':
        topics_input = ['Love', 'War']
    else:
        topics_input = topics_input.split(', ')
    
    print ("Would you like to filter the song dataset on the following variables")
    filter_input = input('\nPlease select 1 to filter or 0 to search entire dataset: ')
    if filter_input == '1':
        df_filtered = UserInterface1(df)
        choice_df = df_filtered.reset_index()
        #print(choice_df.head())
    else:
        choice_df = df
        
    vocabulary_train = VocBuilder(choice_df)
    
    # take the choice of df, either the filtered one or the entire df and pass to inverted index.    
    invertind = makeInvertedIndex(choice_df,vocabulary_train)
    
    andor_input = input('\nPlease select OR to perform OR search, AND to perform AND search!: ')
    # search inverted index using whichever method AND/OR
    if andor_input == 'OR':
        orSearch(invertind,topics_input, choice_df)
    else:
        andSearch(invertind,topics_input, choice_df)

# %%
UserInterface2(df)
# Out:
# In the following steps you will be able to search songs, artists, and albums by Topics and Entities:
#
# Lookup topics such as Mars, Fire, Weapons, Love, Death
#
# Please enter topics  (or type * to select some default topics): God
# Would you like to filter the song dataset on the following variables
#
# Please select 1 to filter or 0 to search entire dataset: 1
# In the following steps you will filter the song dataset on the following variables:
# ID
# artist
# song
# album
# released
# genre
# home_country
# singer_age_at_release
# entity
# topic
# Google_Entities
# overall_sentiment
#
#
# Artist options:  ['Aerosmith', 'Bruno Mars', 'Coldplay', 'Doors', 'Elton John', 'Elvis Presley', 'Grateful Dead', 'Jimi Hendrix', 'John Legend', 'Lady Gaga', 'Linkin Park', 'Maroon 5', 'Metallica', 'Michael Jackson', 'Nickelback', 'Outkast', 'Santana', 'Stevie Wonder', 'Weezer', 'Wu-Tang Clan']
#
# Please select your artists (or type * to select all): Aerosmith
#
# Album options:  ['Pump', 'Permanent Vacation', 'Nine Lives', 'Aerosmith', "Honkin' on Bobo", 'Just Push Play', 'Draw the Line', 'Rock in a Hard Place']
#
# Please select your albums (or type * to select all): *
#
# Country options:  ['United States']
#
# Please select your countries (or type * to select all): *
#
# Genre options:
#
# Please select your genres (or type * to select all): *
#
# Release date options:
#  1960-1969
#  1970-1979
#  1980-1989
#  1990-1999
#  2000-2009
#  2010-Present
#
# Please select your release year (or type * to select all): *
#
# Singer age options:
#  10-19
#  20-29
#  30-39
#  40-49
#  50-59
#
# Please select an age range for singers (or type * to select all): *
#
# ===================================================================
# ===================================================================
#
# The average sentiment of the songs resulting from your search is: -0.29
#
# ===================================================================
#
#
# The top 5 most prevalent topics of the songs resulting from your search are:
#
# Song: "Taste Of India", Artist: Aerosmith, Sentiment: 0.6
#
# Song: "Dream On", Artist: Aerosmith, Sentiment: 0.0
#
# Song: "Lightning Strikes", Artist: Aerosmith, Sentiment: 0.0
#
# Song: "Jaded", Artist: Aerosmith, Sentiment: -0.3
#
# Song: "Magic Touch", Artist: Aerosmith, Sentiment: -0.6
#
# ['India', 'Hell', 'songs', 'English-language', 'Dagger', 'a', 'Ship', 'Got', 'abuse', 'Television', 'Music', 'Sailing', 'an', 'saidI', 'Eye', 'industry', 'Alcohol', 'Age', "Janie's", 'Dream', '10', 'Spit', 'Appetite', 'Glam', 'Creative', 'American', 'Shotgun', 'originating', 'Drama', 'Weapons', 'babe', '(landform)', 'Sweetness', 'objects', 'Fiction', 'Lightning', 'Truth', 'Recorded', 'Déjà', "Hell's", 'Cutting', 'Manhattan', 'Novels', 'recording', 'child', 'Blade', 'Ages', 'Works', 'blues', 'produced', 'Velvet', '(botany)', 'Love', 'Alcoholic', 'rock', 'episodes', 'Pop', 'Crops', 'didn', 'Thunder', 'Aerosmith', 'Vindaloo', 'and', 'Sin', 'Concubinage', 'works', 'Funk', 'singles', 'Starch', 'Vikings', 'Personal', 'Guillotine', 'from', 'ballads', 'music', 'wine', 'Hand', 'weapons', 'Europe', 'Parchment', 'Janie', 'Rock', 'Geffen', 'experience', 'Melee', 'media', 'Kings', 'Literature', 'Yin', 'recordings', 'Culture', 'Song', 'Songs', 'Dawn', 'Rumble', 'metal', 'behaviour', 'series', 'Labellum', 'Improvised', 'identifier', 'Albums', 'albums', 'television', 'yang', 'Knife', 'Grape', 'Ready', 'Hard', 'Medieval', 'Middle', 'firearm', 'Greed', 'callI', 'about', 'Gun', 'Religious', 'Entertainment', 'Knives', 'Long', 'Fermented', 'people', 'Wine', 'tools', 'Early', 'for', 'Honey', 'Laughter', 'Location', 'Kitchen,', 'Viking', 'Artificial', 'Perfume', 'of', 'drinks', 'Records', 'Incense', 'I', 'vu', 'written', 'to', 'Lordy', 'eye', 't', 'Denmark', 'hard', 'Ships', 'ship', 'Sound']
#
# Please select OR to perform OR search, AND to perform AND search!: OR
# Query is: ['God']
#
# Check for: God
# Not found...

# %%
def UserInterface3(df):
    print ("WELCOME!\n")
    key_choice = input('\nTo Perform Filtered Search press 1, To perform Topic Search Press 2: ')

    if key_choice == '1':
        df_filtered = UserInterface1(df)
    else:
        UserInterface2(df)
#     else: 
#         print("Did not catch that!\n")
#         key_choice = input('\nTo Perform Filtered Search press 1, To perform Topic Search Press 2: ')

# %%
UserInterface3(df)
# Out:
# WELCOME!
#
#
# To Perform Filtered Search press 1, To perform Topic Search Press 2: 1
# In the following steps you will filter the song dataset on the following variables:
# ID
# artist
# song
# album
# released
# genre
# home_country
# singer_age_at_release
# entity
# topic
# Google_Entities
# overall_sentiment
#
#
# Artist options:  ['Aerosmith', 'Bruno Mars', 'Coldplay', 'Doors', 'Elton John', 'Elvis Presley', 'Grateful Dead', 'Jimi Hendrix', 'John Legend', 'Lady Gaga', 'Linkin Park', 'Maroon 5', 'Metallica', 'Michael Jackson', 'Nickelback', 'Outkast', 'Santana', 'Stevie Wonder', 'Weezer', 'Wu-Tang Clan']
#
# Please select your artists (or type * to select all): Metallica, Nickelback
#
# Album options:  ['St. Anger', 'All the Right Reasons', 'Curb', 'No Fixed Address']
#
# Please select your albums (or type * to select all): *
#
# Country options:  ['United States']
#
# Please select your countries (or type * to select all): *
#
# Genre options:
#
# Please select your genres (or type * to select all): *
#
# Release date options:
#  1960-1969
#  1970-1979
#  1980-1989
#  1990-1999
#  2000-2009
#  2010-Present
#
# Please select your release year (or type * to select all): 1990-1999
#
# Singer age options:
#  10-19
#  20-29
#  30-39
#  40-49
#  50-59
#
# Please select an age range for singers (or type * to select all): *
#
# ===================================================================
# ===================================================================
#
# The average sentiment of the songs resulting from your search is: -0.35
#
# ===================================================================
#
#
# The top 5 most prevalent topics of the songs resulting from your search are:
#
# Song: "Just For", Artist: Nickelback, Sentiment: -0.2
#
# Song: "Pusher", Artist: Nickelback, Sentiment: -0.5

# %%
df
# Out:
#       ID         artist                     song  \
# 0      1      Aerosmith        Janie's Got A Gun
# 1      2      Aerosmith              Magic Touch
# 2      3      Aerosmith           Taste Of India
# 3      4      Aerosmith                 Dream On
# 4      5      Aerosmith    Eyesight To The Blind
# 5      6      Aerosmith              Falling Off
# 6      7      Aerosmith                    Jaded
# 7      8      Aerosmith         Kings And Queens
# 8      9      Aerosmith        Lightning Strikes
# 9     10     Bruno Mars            Don't Give Up
# 10    11     Bruno Mars             It Will Rain
# 11    12     Bruno Mars       Liquor Store Blues
# 12    13     Bruno Mars      When I Was Your Man
# 13    14     Bruno Mars                  Gorilla
# 14    15     Bruno Mars                  Show Me
# 15    16     Bruno Mars              Young Girls
# 16    17       Coldplay                  Fix You
# 17    18       Coldplay               I Ran Away
# 18    19       Coldplay                 Miracles
# 19    20       Coldplay                    Moses
# 20    21       Coldplay     Swallowed In The Sea
# 21    22       Coldplay             Viva La Vida
# 22    23       Coldplay            White Shadows
# 23    24       Coldplay                   Yellow
# 24    25       Coldplay                  Gravity
# 25    26       Coldplay     Hymn For The Weekend
# 26    27       Coldplay                      Ink
# 27    28          Doors              Love Street
# 28    29          Doors      Orange County Suite
# 29    30          Doors      Crawling King Snake
# ..   ...            ...                      ...
# 93    94        Outkast            Decatur Psalm
# 94    95        Outkast                   Hey Ya
# 95    96        Outkast                  Knowing
# 96    97        Outkast             Mutron Angel
# 97    98        Outkast            Pink And Blue
# 98    99        Outkast                 True Dat
# 99   100        Santana           Shades Of Time
# 100  101        Santana                   Let Me
# 101  102        Santana                   Praise
# 102  103        Santana                 Stand Up
# 103  104  Stevie Wonder         Edge Of Eternity
# 104  105  Stevie Wonder               Front Line
# 105  106  Stevie Wonder           Gotta Have You
# 106  107  Stevie Wonder                 Sir Duke
# 107  108  Stevie Wonder                    Sorry
# 108  109  Stevie Wonder         Isn't She Lovely
# 109  110  Stevie Wonder          Keep On Running
# 110  111         Weezer                 Devotion
# 111  112         Weezer             Don't Let Go
# 112  113         Weezer                  Hold Me
# 113  114         Weezer       Living Without You
# 114  115         Weezer            Beverly Hills
# 115  116         Weezer  Everybody Get Dangerous
# 116  117         Weezer                     I Do
# 117  118         Weezer                     King
# 118  119         Weezer               Photograph
# 119  120         Weezer          Say It Ain't So
# 120  121   Wu-Tang Clan                 Reunited
# 121  122   Wu-Tang Clan               Method Man
# 122  123   Wu-Tang Clan            Second Coming
#
#                                          album  released  \
# 0                                         Pump      1989
# 1                           Permanent Vacation      1987
# 2                                   Nine Lives      1997
# 3                                    Aerosmith      1973
# 4                              Honkin' on Bobo      2004
# 5                                   Nine Lives      1997
# 6                               Just Push Play      2001
# 7                                Draw the Line      1977
# 8                         Rock in a Hard Place      1982
# 9                                Sesame Street      2011
# 10          The Twighlight Saga: Breaking Dawn      2011
# 11                        Doo-Wops & Hooligans      2010
# 12                          Unorthodox Jukebox      2012
# 13                          Unorthodox Jukebox      2012
# 14                          Unorthodox Jukebox      2012
# 15                          Unorthodox Jukebox      2012
# 16                                         X&Y      2005
# 17                                    Coldplay      2002
# 18                                Kaleidoscope      2017
# 19                                   Live 2003      2003
# 20                                         X&Y      2005
# 21   Viva la Vida or Death and All His Friends      2008
# 22                                         X&Y      2005
# 23                                  Parachutes      2000
# 24                                         X&Y      2005
# 25                       A Head Full of Dreams      2015
# 26                               Ghost Stories      2014
# 27                           The Doors (Movie)      1968
# 28                                  L.A. Woman      1971
# 29                                  L.A. Woman      1971
# ..                                         ...       ...
# 93                                     ATLiens      1996
# 94                 Speakerboxxx/The Love Below      2003
# 95                 Speakerboxxx/The Love Below      2003
# 96                                 Whild Peach      2006
# 97                 Speakerboxxx/The Love Below      2003
# 98             Southernplayalisticadillacmuzik      1994
# 99                                     Santana      1969
# 100                                     Shango      1982
# 101                                    Freedom      1987
# 102                                   Marathon      1979
# 103                         Conversation Peace      1995
# 104                       Original Musiquarium      1982
# 105                               Jungle Fever      1991
# 106                   Songs in the Key of Life      1976
# 107                         Conversation Peace      1995
# 108                   Songs in the Key of Life      1976
# 109                           Music of My Mind      1972
# 110                                  Pinkerton      1996
# 111                                     Weezer      2001
# 112                               Make Believe      2005
# 113                                  Maladroit      2002
# 114                               Make Believe      2005
# 115                                     Weezer      2008
# 116                                     Weezer      2001
# 117                                     Weezer      2008
# 118                                     Weezer      2001
# 119                                     Weezer      1994
# 120                            Wu-Tang Forever      1997
# 121                          Enter the Wu-Tang      1993
# 122                            Wu-Tang Forever      1997
#
#                                 genre   home_country  singer_age_at_release  \
# 0                   [Hard rock, Rock]  United States                     41
# 1                   [Hard rock, Rock]  United States                     39
# 2                         [Hard rock]  United States                     49
# 3                [Classic rock, Rock]  United States                     25
# 4                   [Hard rock, Rock]  United States                     56
# 5                         [Hard rock]  United States                     49
# 6                         [Hard rock]  United States                     53
# 7                      [Classic rock]  United States                     29
# 8                         [Hard rock]  United States                     34
# 9                               [Pop]  United States                     26
# 10                              [Pop]  United States                     26
# 11                      [Reggae, Pop]  United States                     25
# 12                              [Pop]  United States                     27
# 13                              [Pop]  United States                     27
# 14                              [Pop]  United States                     27
# 15                              [Pop]  United States                     27
# 16   [Alternative rock, Post-Britpop]        England                     28
# 17                             [Rock]        England                     25
# 18                [Alternative/Indie]        England                     40
# 19                             [Rock]        England                     26
# 20                             [Rock]        England                     28
# 21                             [Rock]        England                     31
# 22                             [Rock]        England                     28
# 23                          [Britpop]        England                     23
# 24                             [Rock]        England                     28
# 25                              [Pop]        England                     38
# 26                [Alternative/Indie]        England                     37
# 27                     [Classic rock]  United States                     24
# 28                     [Classic rock]  United States                     27
# 29                     [Classic rock]  United States                     27
# ..                                ...            ...                    ...
# 93                      [Hip-hop/rap]  United States                     21
# 94                 [Pop, Hip-hop/rap]  United States                     28
# 95                 [Pop, Hip-hop/rap]  United States                     28
# 96                      [Hip-hop/rap]  United States                     31
# 97                 [Pop, Hip-hop/rap]  United States                     28
# 98                      [Hip-hop/rap]  United States                     19
# 99                             [Rock]  United States                     22
# 100                    [Classic rock]  United States                     35
# 101                    [Classic rock]  United States                     40
# 102                            [Rock]  United States                     32
# 103                [Contemporary R&B]  United States                     45
# 104                [Contemporary R&B]  United States                     32
# 105                [Contemporary R&B]  United States                     41
# 106                    [Classic soul]  United States                     26
# 107                [Contemporary R&B]  United States                     45
# 108                    [Classic soul]  United States                     26
# 109                    [Classic soul]  United States                     22
# 110               [Alternative/Indie]  United States                     26
# 111               [Alternative/Indie]  United States                     31
# 112               [Alternative/Indie]  United States                     35
# 113               [Alternative/Indie]  United States                     32
# 114               [Alternative/Indie]  United States                     35
# 115               [Alternative/Indie]  United States                     38
# 116               [Alternative/Indie]  United States                     31
# 117               [Alternative/Indie]  United States                     38
# 118               [Alternative/Indie]  United States                     31
# 119               [Alternative/Indie]  United States                     24
# 120                     [Hip-hop/rap]  United States                     29
# 121                     [Hip-hop/rap]  United States                     25
# 122                     [Hip-hop/rap]  United States                     29
#
#                                                 entity  \
# 0    [{"Janie's Got a Gun": 0.2361}, {'Honey': 0.05...
# 1                   [{'Shotgun': 0.1503}, {'babe': 0}]
# 2    [{'Incense': 0.2548}, {'Sweetness of wine': 0....
# 3    [{'Dawn': 0.2379}, {'Sin': 0.2023}, {'Laughter...
# 4          [{'God': 0.143}, {'Lordy': 0}, {'Lord': 0}]
# 5    [{'t callI': 0}, {'I saidI': 0}, {'I didn': 0}...
# 6                    [{'Velvet': 0.0309}, {'Love': 0}]
# 7    [{'Vikings': 0.1653}, {'Ship': 0.1323}, {'Trut...
# 8    [{'Knife': 0.3647}, {'Dagger': 0.3184}, {"Hell...
# 9    [{'Roller skates': 0.3822}, {'Bruno Mars': 0.2...
# 10   [{'Morphine': 0.1131}, {'Makin (islands)': 0.0...
# 11   [{'Superman': 0.1991}, {'Distilled beverage': ...
# 12   [{'When I Was Your Man': 0.5615}, {'Pride': 0....
# 13   [{'Cocaine': 0.1768}, {'Gorilla': 0.173}, {'De...
# 14   [{'Land of Toys': 0.22}, {'Girl': 0}, {'Darlin...
# 15              [{'2017-12-03T00:00:00.000-05:00': 0}]
# 16                               [{'Fix You': 0.3404}]
# 17              [{'2017-12-03T00:00:00.000-05:00': 0}]
# 18   [{'Song structure': 0.5095}, {'Refrain': 0.230...
# 19                    [{'Rain': 0.1774}, {'Moses': 0}]
# 20        [{'You Belong with Me': 0.2827}, {'100': 0}]
# 21   [{'Saint Peter': 0.2547}, {'Choir': 0.2429}, {...
# 22   [{'Outer space': 0.2331}, {'Tide': 0.1813}, {'...
# 23
# 24   [{'Sky': 0.1825}, {'Gravity': 0.129}, {'2017-1...
# 25   [{'Sky': 0.2866}, {'Rain': 0.2417}, {'Flood': ...
# 26   [{'Tattoo': 0.1256}, {'Pocketknife': 0.04381},...
# 27   [{'Diamond': 0.06262}, {'Love Street (stadium)...
# 28   [{'Door': 0.156}, {'Chicago': 0.1352}, {'Mount...
# 29   [{'Crawling King Snake': 0.239}, {'Snake': 0.1...
# ..                                                 ...
# 93   [{'Miser': 0.2128}, {'Funeral': 0.1708}, {'Big...
# 94          [{'Hey Ya!': 0.4774}, {'Nothing': 0.1801}]
# 95   [{'In Living Color': 0.2438}, {'Nothing': 0.20...
# 96   [{'Prophecy': 0.275}, {'Tropical cyclone': 0.2...
# 97   [{'Baby talk': 0.197}, {'Miss': 0}, {'Claire H...
# 98   [{'Truth': 0.2592}, {'Fuck': 0.239}, {'Outkast...
# 99
# 100
# 101                                 [{'Soul': 0.1798}]
# 102                                      [{'Love': 0}]
# 103  [{'Ounce': 0.1161}, {'Pie in the Sky (TV serie...
# 104  [{'Agent Orange': 0.3492}, {'Purple Heart': 0....
# 105   [{'Visual perception': 0.2227}, {'Eye': 0.1809}]
# 106  [{'Music': 0}, {'Sachmo': 0}, {'Basie': 0}, {'...
# 107                    [{'Beggin': 0}, {'Breakin': 0}]
# 108  [{'Heaven': 0.3304}, {'God': 0.2849}, {'1': 0}...
# 109
# 110  [{'United States': 0.1186}, {'Refrain': 0.0734...
# 111                  [{'Gods': 0}, {'2': 0}, {'4': 0}]
# 112
# 113                         [{'Ohhh': 0}, {'Whoa': 0}]
# 114  [{'Boarding school': 0.2405}, {'Nothing': 0.15...
# 115  [{'Chair': 0.2343}, {'Baseball': 0.2288}, {'Ni...
# 116             [{'2017-12-03T00:00:00.000-05:00': 0}]
# 117              [{'Disco': 0.322}, {'Beer': 0.09808}]
# 118                                         [{'3': 0}]
# 119  [{'Water slide': 0.04422}, {'Icebox': 0.02647}...
# 120  [{'Wu-Tang Clan': 0.3854}, {'RZA': 0.3677}, {'...
# 121  [{'Wu-Tang Clan': 0.8759}, {'Inspectah Deck': ...
# 122  [{'Wu-Tang Clan': 0.38}, {'Hip hop music': 0.3...
#
#                                                  topic  \
# 0    [{'Songs written': 1}, {'Aerosmith songs': 1},...
# 1    [{'Albums': 0.5973}, {'Recorded music': 0.5719...
# 2    [{'Wine': 0.7881}, {'Recorded music': 0.7072},...
# 3    [{'Dawn': 0.3767}, {'Entertainment': 0.3653}, ...
# 4    [{'Shacharit for Shabbat and Yom Tov': 0.7511}...
# 5    [{'Literature': 0.3241}, {'Fiction': 0.3006}, ...
# 6    [{'Recorded music': 0.7737}, {'Albums': 0.6503...
# 7    [{'Viking Age': 0.3941}, {'Medieval Denmark': ...
# 8    [{'Blade weapons': 1}, {'Melee weapons': 0.958...
# 9    [{'Roller skates': 0.6051}, {'Recorded music':...
# 10   [{'Television episodes': 0.4698}, {'American t...
# 11   [{'Recorded music': 0.4423}, {'Distilled bever...
# 12   [{'When I Was Your Man': 1}, {'Entertainment':...
# 13   [{'Gorilla': 0.5492}, {'Television episodes': ...
# 14   [{'Television episodes': 0.496}, {'American te...
# 15   [{'Entertainment': 0.4974}, {'Albums': 0.4352}...
# 16   [{'Fix You': 0.8096}, {'Television series': 0....
# 17   [{'Astronomy': 0.4279}, {'Mythology': 0.303}, ...
# 18   [{'Song structure': 1}, {'Songs': 1}, {'Musica...
# 19   [{'Television episodes': 0.5402}, {'American t...
# 20   [{'You Belong with Me': 0.777}, {'Recorded mus...
# 21   [{'Choir': 0.5065}, {'Shield': 0.4688}, {'Voca...
# 22   [{'Outer space': 0.4886}, {'Albums': 0.4568}, ...
# 23   [{'Medicine': 0.2818}, {'Health sciences': 0.1...
# 24   [{'Gravity': 0.3336}, {'American television ep...
# 25   [{'Physical geography': 0.8714}, {'Sky': 0.741...
# 26   [{'Tattoo': 0.2619}, {'Tattooing': 0.2584}, {'...
# 27   [{'Literature': 0.199}, {'Fiction': 0.1831}, {...
# 28   [{'Entertainment': 0.4211}, {'Novels': 0.2875}...
# 29   [{'John Lee Hooker songs': 1}, {'Eric Burdon s...
# ..                                                 ...
# 93   [{'Entertainment': 0.4881}, {'Miser': 0.337}, ...
# 94   [{'Hey Ya!': 1}, {'Recorded music': 0.5482}, {...
# 95   [{'In Living Color': 0.3861}, {'Nothing': 0.32...
# 96   [{'Tropics': 1}, {'Storm': 1}, {'Tropical cycl...
# 97   [{'Television episodes': 0.5245}, {'American t...
# 98   [{'Metaphysics': 1}, {'Philosophical theories'...
# 99   [{'Television episodes': 0.6233}, {'American t...
# 100  [{'Albums': 0.1367}, {'Recorded music': 0.1015...
# 101  [{'Recorded music': 0.9617}, {'Songs': 0.7845}...
# 102  [{'Albums': 0.7305}, {'Recorded music': 0.645}...
# 103  [{'Albums': 0.541}, {'Recorded music': 0.4801}...
# 104  [{'Agent Orange': 0.5529}, {'Shacharit for Sha...
# 105  [{'Visual perception': 0.6414}, {'Eye': 0.5211...
# 106  [{'Entertainment': 0.3166}, {'Music': 0.3002},...
# 107  [{'Television episodes': 0.4027}, {'Television...
# 108  [{'Religion': 1}, {'Religious belief and doctr...
# 109  [{'Albums': 0.722}, {'Recorded music': 0.6635}...
# 110  [{'Literature': 0.4897}, {'Songs': 0.4582}, {'...
# 111  [{'Religion': 0.5849}, {'Religious belief and ...
# 112  [{'Literature': 0.2484}, {'Fiction': 0.1576}, ...
# 113  [{'Albums': 0.9051}, {'Recorded music': 0.8182...
# 114  [{'Entertainment': 0.5319}, {'Fiction': 0.493}...
# 115  [{'Entertainment': 0.3772}, {'Chair': 0.3709},...
# 116            [{'The Sun (United Kingdom)': 0.05684}]
# 117  [{'Disco': 0.5098}, {'Music': 0.4775}, {'Enter...
# 118  [{'Entertainment': 0.4747}, {'Creative works':...
# 119  [{'Albums': 0.4985}, {'Recorded music': 0.4736...
# 120  [{'Wu-Tang Clan': 0.8967}, {'African-American ...
# 121  [{'Wu-Tang Clan': 1}, {'Musical collectives': ...
# 122  [{'Wu-Tang Clan': 1}, {'Hip hop music': 0.5511...
#
#                                        Google_Entities  overall_sentiment
# 0    [{'Janie': 0.62619865}, {'honey': 0.10297375},...               -0.7
# 1    [{'fire burnin': 0.20596175}, {'Cause': 0.0714...               -0.6
# 2    [{'kind': 0.3166986}, {'taste': 0.23181729}, {...                0.6
# 3    [{'Lord': 0.2157075}, {'Everybody': 0.05828119...                0.0
# 4    [{'girl': 0.32739675}, {'woman': 0.21680547}, ...                0.2
# 5    [{'way': 0.24776857}, {'man': 0.14769095}, {'h...               -0.6
# 6    [{'child': 0.46256787}, {'one': 0.3776241}, {'...               -0.3
# 7    [{'greed Maidens': 0.2779506}, {'lords': 0.067...               -0.7
# 8    [{'lid': 0.34622723}, {'Boys': 0.13296318}, {'...                0.0
# 9    [{'something': 0.5476195}, {'advice': 0.077285...               -0.7
# 10   [{'baby': 0.70477825}, {'lot': 0.060874313}, {...               -0.2
# 11   [{'pain': 0.19992845}, {'sorrow': 0.1314703}, ...                0.1
# 12   [{'first': 0.4813333}, {'bed': 0.09736296}, {'...               -0.1
# 13   [{'love': 0.67570144}, {'liquor': 0.020023568}...                0.6
# 14   [{'Right': 0.4256778}, {'eyes': 0.12824686}, {...                0.0
# 15   [{'girls': 0.48842955}, {'death': 0.23196444},...               -0.2
# 16   [{'best': 0.45081758}, {'face': 0.36265737}, {...               -0.4
# 17   [{'fool mess': 0.78651136}, {'thing': 0.041085...               -0.8
# 18   [{'eyes': 0.1560939}, {'Oh': 0.11912149}, {'wo...                0.3
# 19   [{'refuge': 0.39671046}, {'thing': 0.19097403}...                0.0
# 20   [{'one': 0.45624954}, {'sea': 0.15609959}, {'t...               -0.4
# 21   [{'king': 0.13179031}, {'world': 0.09064897}, ...               -0.2
# 22   [{'boy': 0.48215535}, {'Part': 0.04197081}, {'...                0.1
# 23   [{'thing': 0.47526285}, {'everything': 0.07616...                0.7
# 24   [{'heart beating': 0.32612687}, {'Honey': 0.16...               -0.1
# 25   [{'drink': 0.12074792}, {'drink': 0.116138674}...                0.2
# 26   [{'all': 0.46611997}, {'tattoo': 0.18165842}, ...               -0.3
# 27   [{'creatures': 0.17118108}, {'house': 0.108879...                0.9
# 28   [{'someone': 0.5374064}, {'trip': 0.23632489},...               -0.3
# 29   [{"Crawlin' King Snake": 0.20579411}, {'Gonna'...               -0.1
# ..                                                 ...                ...
# 93   [{'everything': 0.17233056}, {'bout': 0.167784...               -0.1
# 94   [{'baby': 0.36805284}, {'feeling': 0.06573426}...                0.1
# 95   [{'way': 0.48329866}, {'Wanda': 0.070144154}, ...               -0.4
# 96   [{'friend': 0.2931701}, {'idea': 0.07374211}, ...                0.7
# 97   [{'head': 0.20940079}, {'baby blue': 0.1228607...               -0.4
# 98   [{'outkast': 0.31333974}, {'someone': 0.082627...               -0.4
# 99   [{'things': 0.4046108}, {'things': 0.22081237}...               -0.5
# 100  [{'people': 0.6808881}, {'summer sound': 0.180...                0.2
# 101  [{'Something': 0.24638419}, {'place': 0.212228...                0.0
# 102  [{'change': 0.31173095}, {'Love': 0.11229199},...                0.8
# 103  [{'Well': 0.49929705}, {'eternity': 0.17086165...               -0.2
# 104  [{'veteran': 0.6578626}, {'Vietnam': 0.0623369...               -0.1
# 105  [{'sight': 0.8085694}, {'reality': 0.04920112}...               -0.4
# 106  [{'Music': 0.3840953}, {'people': 0.10754415},...                0.0
# 107  [{'baby': 0.5488464}, {'cause': 0.314183}, {'B...               -0.6
# 108  [{'love': 0.5214803}, {'Boy': 0.06990244}, {'l...                0.8
# 109  [{'love': 0.3964615}, {'folks': 0.12211413}, {...                0.6
# 110  [{'friend': 0.5709584}, {'girlfriend': 0.31649...               -0.2
# 111  [{'arms': 0.15354982}, {'girl': 0.08056851}, {...               -0.6
# 112  [{'things': 0.34374595}, {'cause': 0.25412083}...                0.0
# 113  [{'friend': 0.92958146}, {'house': 0.035410486...                0.2
# 114  [{'thing': 0.3963116}, {'automobile': 0.118633...               -0.7
# 115  [{'Everybody': 0.51919657}, {'some': 0.0863783...                0.1
# 116  [{'times': 0.7171163}, {'games': 0.19160807}, ...                0.0
# 117  [{'king': 0.45521715}, {'baby': 0.17575765}, {...                0.0
# 118  [{'heart': 0.5177235}, {'Cause': 0.065733135},...                0.0
# 119  [{'water slide': 0.20154977}, {'life taker': 0...                0.5
# 120  [{'motherfuckers': 0.20940317}, {'motherfucker...               -0.4
# 121                                                                  -0.4
# 122                                                                  -0.3
#
# [123 rows x 12 columns]
