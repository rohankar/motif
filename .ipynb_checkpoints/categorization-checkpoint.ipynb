# %%
import IPython
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib
import sklearn
import matplotlib
import seaborn as sns
import graphviz

#https://github.com/TextRazor/textrazor-python/blob/master/textrazor.py

# %%
data = pd.read_csv("songlyrics.csv", low_memory=False)
data.head()
# Out:
#    Unnamed: 0  ID     artist                   song  \
# 0           0   1  Aerosmith      Janie's Got A Gun
# 1           1   2  Aerosmith            Magic Touch
# 2           2   3  Aerosmith         Taste Of India
# 3           3   4  Aerosmith               Dream On
# 4           4   5  Aerosmith  Eyesight To The Blind
#
#                                                link  \
# 0       /a/aerosmith/janies+got+a+gun_20004444.html
# 1            /a/aerosmith/magic+touch_20004437.html
# 2         /a/aerosmith/taste+of+india_20004375.html
# 3               /a/aerosmith/dream+on_20004389.html
# 4  /a/aerosmith/eyesight+to+the+blind_10002988.html
#
#                                                 text               album  \
# 0  Dum, dum, dum, honey what have you done  \rDum...                Pump
# 1  Somebody better call a doctor, doctor  \rOr wa...  Permanent Vacation
# 2  God I love the sweet taste of India  \rLingers...          Nine Lives
# 3  Every time when I look in the mirror  \rAll th...           Aerosmith
# 4  Well, well, well, well  \r  \rYou were talking...     Honkin' on Bobo
#
#    released               genre   home_country  singer_age_at_release  \
# 0      1989     Hard rock, Rock  United States                     41
# 1      1987     Hard rock, Rock  United States                     39
# 2      1997           Hard rock  United States                     49
# 3      1973  Classic rock, Rock  United States                     25
# 4      2004     Hard rock, Rock  United States                     56
#
#                                               entity  \
# 0            ["Janie's Got a Gun", 'Honey', 'Janie']
# 1                                ['Shotgun', 'babe']
# 2  ['Incense', 'Sweetness of wine', 'Wine', 'Funk...
# 3               ['Dawn', 'Sin', 'Laughter', 'Dream']
# 4                           ['God', 'Lordy', 'Lord']
#
#                                                topic
# 0  ['Songs written', 'Aerosmith songs', 'Song rec...
# 1  ['Albums', 'Recorded music', 'Music media', 'T...
# 2  ['Wine', 'Recorded music', 'Grape', 'Fermented...
# 3  ['Dawn', 'Entertainment', 'Fiction', 'Literatu...
# 4  ['Shacharit for Shabbat and Yom Tov', 'Shabbat...

# %%
#!pip install textrazor
import textrazor

textrazor.api_key = "5cc54549cdb73be40c1f4310f3603d9a2d8bfd232964f94eff8a7a81"
client = textrazor.TextRazor(extractors=["entities", "topics", "categories"])

# %%
#initialize blank columns
data['entity'] = ""
data['topic'] = ""

data['entity'] = data['entity'].astype(object)
data['topic'] = data['topic'].astype(object)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'artist', 'song', 'link', 'text', 'album',
#        'released', 'genre', 'home_country', 'singer_age_at_release', 'entity',
#        'topic'],
#       dtype='object')

# %%
data2 = data.iloc[0:4, :]
data2.head()
data2['topic'] = data2['topic'].astype(object)
# Out:
# C:\Anaconda\envs\Data-X\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def rprint(obj, depth):
    print(str(obj)[:depth])

# %%
for i, row in data.iterrows():
    song1 = data['text'][i]
    response = client.analyze(song1)
    l1 = []
    l2 = []
    topics = list(response.topics())    
    topics.sort(key=lambda x: x.score, reverse=True)
    entities = list(response.entities())
    entities.sort(key=lambda x: x.relevance_score, reverse=True)
    seen1 = set()
    seen2 = set()
    for topic in topics[:10]:
        if topic.id not in seen1:
            #topic.label
            l1.append({topic.label:topic.score})
            seen1.add(topic.label)
        data['topic'][i] = l1

    for entity in entities[:20]:
        if entity.id not in seen2:
            l2.append({entity.id:entity.relevance_score})
            seen2.add(entity.id)
        data['entity'][i] = l2
# Out:
# C:\Anaconda\envs\Data-X\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\envs\Data-X\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data.head(30)
# Out:
#     Unnamed: 0  ID      artist                   song  \
# 0            0   1   Aerosmith      Janie's Got A Gun
# 1            1   2   Aerosmith            Magic Touch
# 2            2   3   Aerosmith         Taste Of India
# 3            3   4   Aerosmith               Dream On
# 4            4   5   Aerosmith  Eyesight To The Blind
# 5            5   6   Aerosmith            Falling Off
# 6            6   7   Aerosmith                  Jaded
# 7            7   8   Aerosmith       Kings And Queens
# 8            8   9   Aerosmith      Lightning Strikes
# 9            9  10  Bruno Mars          Don't Give Up
# 10          10  11  Bruno Mars           It Will Rain
# 11          11  12  Bruno Mars     Liquor Store Blues
# 12          12  13  Bruno Mars    When I Was Your Man
# 13          13  14  Bruno Mars                Gorilla
# 14          14  15  Bruno Mars                Show Me
# 15          15  16  Bruno Mars            Young Girls
# 16          16  17    Coldplay                Fix You
# 17          17  18    Coldplay             I Ran Away
# 18          18  19    Coldplay               Miracles
# 19          19  20    Coldplay                  Moses
# 20          20  21    Coldplay   Swallowed In The Sea
# 21          21  22    Coldplay           Viva La Vida
# 22          22  23    Coldplay          White Shadows
# 23          23  24    Coldplay                 Yellow
# 24          24  25    Coldplay                Gravity
# 25          25  26    Coldplay   Hymn For The Weekend
# 26          26  27    Coldplay                    Ink
# 27          27  28       Doors            Love Street
# 28          28  29       Doors    Orange County Suite
# 29          29  30       Doors    Crawling King Snake
#
#                                                 link  \
# 0        /a/aerosmith/janies+got+a+gun_20004444.html
# 1             /a/aerosmith/magic+touch_20004437.html
# 2          /a/aerosmith/taste+of+india_20004375.html
# 3                /a/aerosmith/dream+on_20004389.html
# 4   /a/aerosmith/eyesight+to+the+blind_10002988.html
# 5             /a/aerosmith/falling+off_20004368.html
# 6                   /a/aerosmith/jaded_20004303.html
# 7            /a/aerosmith/kings+queens_20004137.html
# 8       /a/aerosmith/lightning+strikes_20004188.html
# 9           /b/bruno+mars/dont+give+up_20989970.html
# 10          /b/bruno+mars/it+will+rain_20984444.html
# 11    /b/bruno+mars/liquor+store+blues_20890846.html
# 12   /b/bruno+mars/when+i+was+your+man_21048076.html
# 13               /b/bruno+mars/gorilla_21048075.html
# 14               /b/bruno+mars/show+me_21048081.html
# 15           /b/bruno+mars/young+girls_21048074.html
# 16                 /c/coldplay/fix+you_10069035.html
# 17              /c/coldplay/i+ran+away_20308952.html
# 18                /c/coldplay/miracles_21091916.html
# 19                   /c/coldplay/moses_10068978.html
# 25  [{'Sky': 0.2866}, {'Rain': 0.2417}, {'Flood': ...
# 26  [{'Tattoo': 0.1256}, {'Pocketknife': 0.04381},...
# 27  [{'Diamond': 0.06262}, {'Love Street (stadium)...
# 28  [{'Door': 0.156}, {'Chicago': 0.1352}, {'Mount...
# 29  [{'Crawling King Snake': 0.239}, {'Snake': 0.1...
#
#                                                 topic
# 0   [{'Songs written': 1}, {'Aerosmith songs': 1},...
# 1   [{'Albums': 0.5973}, {'Recorded music': 0.5719...
# 2   [{'Wine': 0.7881}, {'Recorded music': 0.7072},...
# 3   [{'Dawn': 0.3767}, {'Entertainment': 0.3653}, ...
# 4   [{'Shacharit for Shabbat and Yom Tov': 0.7511}...
# 5   [{'Literature': 0.3241}, {'Fiction': 0.3006}, ...
# 6   [{'Recorded music': 0.7737}, {'Albums': 0.6503...
# 7   [{'Viking Age': 0.3941}, {'Medieval Denmark': ...
# 8   [{'Blade weapons': 1}, {'Melee weapons': 0.958...
# 9   [{'Roller skates': 0.6051}, {'Recorded music':...
# 10  [{'Television episodes': 0.4698}, {'American t...
# 11  [{'Recorded music': 0.4423}, {'Distilled bever...
# 12  [{'When I Was Your Man': 1}, {'Entertainment':...
# 13  [{'Gorilla': 0.5492}, {'Television episodes': ...
# 14  [{'Television episodes': 0.496}, {'American te...
# 15  [{'Entertainment': 0.4974}, {'Albums': 0.4352}...
# 16  [{'Fix You': 0.8096}, {'Television series': 0....
# 17  [{'Astronomy': 0.4279}, {'Mythology': 0.303}, ...
# 18  [{'Song structure': 1}, {'Songs': 1}, {'Musica...
# 19  [{'Television episodes': 0.5402}, {'American t...
# 20  [{'You Belong with Me': 0.777}, {'Recorded mus...
# 21  [{'Choir': 0.5065}, {'Shield': 0.4688}, {'Voca...
# 22  [{'Outer space': 0.4886}, {'Albums': 0.4568}, ...
# 23  [{'Medicine': 0.2818}, {'Health sciences': 0.1...
# 24  [{'Gravity': 0.3336}, {'American television ep...
# 25  [{'Physical geography': 0.8714}, {'Sky': 0.741...
# 26  [{'Tattoo': 0.2619}, {'Tattooing': 0.2584}, {'...
# 27  [{'Literature': 0.199}, {'Fiction': 0.1831}, {...
# 28  [{'Entertainment': 0.4211}, {'Novels': 0.2875}...
# 29  [{'John Lee Hooker songs': 1}, {'Eric Burdon s...

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('songlyrics_cat_scores.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
data.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# ### Everything beyond this is just to test

# %%
data2['entity'][3]
# Out:
# ['Dawn', 'Sin', 'Laughter', 'Dream']

# %%
song2 = data['text'][3]
song2
# Out:
# "Every time when I look in the mirror  \rAll these lines on my face getting clearer  \rThe past is gone  \rIt went by, like dusk to dawn  \rIsn't that the way  \rEverybody's got the dues in life to pay  \r  \rI know nobody knows  \rWhere it comes and where it goes  \rI know it's everybody's sin  \rYou got to lose to know how to win  \r  \rHalf my life  \rIs books, written pages  \rLive and learn from fools and  \rFrom sages  \rYou know it's true, oh  \rAll the things come back to you  \r  \rSing with me, sing for the year  \rSing for the laughter, sing for the tear  \rSing with me, just for today  \rMaybe tomorrow, the good Lord will take you away  \r  \rYeah, sing with me, sing for the year  \rSing for the laughter, sing for the tear  \rSing with me, just for today  \rMaybe tomorrow, the good Lord will take you away  \r  \rDream on  \rDream on  \rDream on  \rDream until your dreams come true  \rDream on  \rDream on  \rDream on  \rDream until your dreams come true  \rDream on  \rDream on  \rDream on  \rDream on  \rDream on  \rDream on  \rDream on  \r  \rSing with me, sing for the year  \rSing for the laughter, sing for the tear  \rSing with me, just for today  \rMaybe tomorrow, the good Lord will take you away  \rSing with me, sing for the year  \rSing for the laughter, sing for the tear  \rSing with me, just for today  \rMaybe tomorrow, the good Lord will take you away.\r\r"

# %%
response = client.analyze(song2)

for entity in response.entities():
    print (entity.id, entity.relevance_score, entity.confidence_score, entity.freebase_types)
# Out:
# Dawn 0.2379 2.093 []
# Laughter 0.1001 1.8 ['/people/cause_of_death', '/media_common/quotation_subject', '/book/book_subject']
# Laughter 0.1001 1.8 ['/people/cause_of_death', '/media_common/quotation_subject', '/book/book_subject']
# Dream 0 0.5 ['/location/location']
# Laughter 0.1001 1.8 ['/people/cause_of_death', '/media_common/quotation_subject', '/book/book_subject']
# Laughter 0.1001 1.8 ['/people/cause_of_death', '/media_common/quotation_subject', '/book/book_subject']
# Dream 0 0.5 ['/location/location']
# Dream 0 0.5 ['/location/location']
# Dream 0 0.5 ['/location/location']
# Dream 0 0.5 ['/location/location']
# Dream 0 0.5 ['/location/location']
# Sin 0.2023 1.005 ['/event/speech_topic', '/book/book_subject', '/media_common/quotation_subject']
# Dream 0 0.5 ['/location/location']
# Dream 0 0.5 ['/location/location']
# Dream 0 0.5 ['/location/location']
# Dream 0 0.5 ['/location/location']
# Dream 0 0.5 ['/location/location']
# Dream 0 0.5 ['/location/location']
# Dream 0 0.5 ['/location/location']
# Dream 0 0.5 ['/location/location']
# Dream 0 0.5 ['/location/location']

# %%
# for category in response.categories():
#     print (category.category_id, category.label, category.score)

# %%
entities = list(response.entities())
entities.sort(key=lambda x: x.relevance_score, reverse=True)
l2 = []
seen = set()
for entity in entities:
        if entity.id not in seen:
            print (entity.id, entity.relevance_score, entity.confidence_score, entity.freebase_types)
            print(entity.id)
            seen.add(entity.id)
# Out:
# Dawn
# Sin
# Laughter
# Dream

# %%
# for topic in response.topics()[:5]:
#     if topic.score > 0.3:
#         print(topic.label)
# Out:
# Recorded music
# Distilled beverage
# American musicians
# Entertainment
# Music

# %%
# topics = list(response.topics())
# topics.sort(key=lambda x: x.score, reverse=True)
# l2 = []
# seen = set()
# for topic in topics[:5]:
#         if entity.id not in seen:
#             #topic.label
#             l2.append(topic.label)
#             seen.add(topic.id)
# print(l2)
# Out:
# ['Recorded music', 'Distilled beverage', 'American musicians', 'Entertainment', 'Music']
